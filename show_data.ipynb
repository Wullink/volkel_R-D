# %%
import duckdb

con = duckdb.connect()
# Check schema and first 5 rows
print("Parquet Schema:")
con.sql("DESCRIBE SELECT * FROM read_parquet('./area_15.parquet')").show()

print("\nData Preview:")
con.sql("SELECT * FROM read_parquet('./area_15.parquet') LIMIT 5").show()
con.close()
# Out:
# Parquet Schema:
# ...
